# %%
# Extracting German to english Corpus
import requests

filename = 'de-en.tgz'
# ...extract zip file
import tarfile

tar = tarfile.open(filename, mode='r')
tar.extractall()
tar.close()

# %%
# Extracting French to english Corpus
import requests

filename = 'fr-en.tgz'
# ...extract zip file
import tarfile

tar = tarfile.open(filename, mode='r')
tar.extractall()
tar.close()

# %% [markdown]
# ### Problem 1 - choosing French to English

# %%
# Load Data
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, mode='rt', encoding='utf-8')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# %%
# split a loaded document into sentences
def to_sentences(doc):
    return doc.strip().split('\n')

# %%
# shortest and longest sentence lengths
def sentence_lengths(sentences):
    lengths = [len(s.split()) for s in sentences]
    return min(lengths), max(lengths)

# %%
# load English data
filename = 'fr-en.en'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('English data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# English data: sentences=1000, min=1, max=79

# %%
# load French data
filename = 'fr-en.fr'
doc = load_doc(filename)
sentences = to_sentences(doc)
minlen, maxlen = sentence_lengths(sentences)
print('French data: sentences=%d, min=%d, max=%d' % (len(sentences), minlen, maxlen))
# Out:
# French data: sentences=1000, min=2, max=80

# %%
# Removing punctualition making words to lower case
def clean_lines(lines):
    cleaned = list()
    # prepare regex for char filtering
    re_print = re.compile('[^%s]' % re.escape(string.printable))
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for line in lines:
        # normalize unicode characters
        line = normalize('NFD', line).encode('ascii', 'ignore')
        line = line.decode('UTF-8')
        # tokenize on white space
        line = line.split()
        # convert to lower case
        line = [word.lower() for word in line]
        # remove punctuation from each token
        line = [word.translate(table) for word in line]
        # remove non-printable chars form each token
        line = [re_print.sub('', w) for w in line]
        # remove tokens with numbers in them
        line = [word for word in line if word.isalpha()]
        # store as string
        cleaned.append(' '.join(line))
    return cleaned

# %%
# save a list of clean sentences to file
def save_clean_sentences(sentences, filename):
    dump(sentences, open(filename, 'wb'))
    print('Saved: %s' % filename)

# %%
from __future__ import print_function
import sys
from collections import defaultdict
import time
import collections
import logging
import pandas as pd

# %% [markdown]
# Problem 1: Initialize with uniform probability

# %%
#Initialize t(f|e) values with uniform distribution
def init_t(source_corpus, foreign_corpus):
    source = open(source_corpus, "r")
    foreign = open(foreign_corpus, "r")
    unique_f = len(set(w.lower() for w in open(foreign_corpus).read().split()))
    t = collections.defaultdict(dict)
    for e_line, f_line in zip(open(source_corpus), open(foreign_corpus)):
        e_set = set(e_line.strip().split(" "))
        e_set.add("NULL")
        for e in e_set:
            for f in set(f_line.strip().split(" ")):
                # t(f|e) is given by 1 over unique foreign words + 1 (NULL)
                t[e][f] = 1/float(unique_f + 1)
    return t

# %%
 t = init_t("fr-en.en","fr-en.fr")

# %%
Prob = pd.DataFrame(t)
Prob
# Out:
#                         of            the  Resumption           NULL  session  \
# !             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# "             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# %             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# '             1.169329e-70  4.271191e-130         NaN  4.657360e-144      NaN
# (             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# )             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# ,             3.367194e-02   1.057705e-01         NaN   1.122712e-03      NaN
# -             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# -1999         0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# -20           0.000000e+00            NaN         NaN   0.000000e+00      NaN
# -20ÂºC        0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# -40           0.000000e+00            NaN         NaN   0.000000e+00      NaN
# -40Âº                  NaN   0.000000e+00         NaN   0.000000e+00      NaN
# .             3.442673e-29   2.862664e-19         NaN   7.275667e-01      0.0
# ....          0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# /             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 000           0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 0066          0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 094           0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 1             0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 1,2           0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 10            0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 101           0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 11            0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 110           0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 12                     NaN            NaN         NaN   0.000000e+00      NaN
# 13            0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 143                    NaN            NaN         NaN   0.000000e+00      NaN
# 148           0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# 15            0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# ...                    ...            ...         ...            ...      ...
# Ã©videmment   0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vidence     0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vident               NaN   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©videntes             NaN   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vite        0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©viter       0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vitÃ©       0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vitÃ©s               NaN   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vocation    0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©volue       0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©voluer               NaN   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©volution    0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©volutions   0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©voque       0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©voquer      0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©voquez      0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©voquÃ©      0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©voquÃ©es    0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã©vÃ©nement            NaN            NaN         NaN   0.000000e+00      NaN
# Ã©vÃ©nements  0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ãªtes         0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ãªtre         0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã®les         0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã´ter                  NaN   0.000000e+00         NaN   0.000000e+00      NaN
# Ã‰carter               NaN            NaN         NaN   0.000000e+00      NaN
# Ã‰tant                 NaN   0.000000e+00         NaN   0.000000e+00      NaN
# Ã‰tat         0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã‰tats        0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã‰tats-Unis   0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
# Ã€            0.000000e+00   0.000000e+00         NaN   0.000000e+00      NaN
#
#               happy           year  festive  resumed       European  \
# !               NaN            NaN      NaN      NaN   0.000000e+00
# "               NaN            NaN      NaN      NaN   0.000000e+00
# %               NaN   0.000000e+00      NaN      NaN   0.000000e+00
# '               NaN   0.000000e+00      NaN      NaN   0.000000e+00
# (               NaN            NaN      NaN      NaN   0.000000e+00
# )               NaN            NaN      NaN      NaN   0.000000e+00
# ,               0.0   2.565763e-54      NaN      NaN   6.560602e-85
# -               NaN   0.000000e+00      NaN      NaN   0.000000e+00
# -1999           NaN            NaN      NaN      NaN            NaN
# -20             NaN            NaN      NaN      NaN            NaN
# -20ÂºC          NaN            NaN      NaN      NaN   0.000000e+00
# -40             NaN            NaN      NaN      NaN            NaN
# -40Âº           NaN            NaN      NaN      NaN            NaN
# .               0.0  9.751169e-172      0.0      0.0  1.243338e-103
# ....            NaN            NaN      NaN      NaN            NaN
# /               NaN            NaN      NaN      NaN   0.000000e+00
# 000             NaN            NaN      NaN      NaN            NaN
# 0066            NaN            NaN      NaN      NaN   0.000000e+00
# 094             NaN            NaN      NaN      NaN            NaN
# 1               NaN            NaN      NaN      NaN            NaN
# 1,2             NaN   0.000000e+00      NaN      NaN            NaN
# 10              NaN            NaN      NaN      NaN            NaN
# 101             NaN            NaN      NaN      NaN            NaN
# 11              NaN            NaN      NaN      NaN            NaN
# 110             NaN            NaN      NaN      NaN            NaN
# 12              NaN            NaN      NaN      NaN            NaN
# 13              NaN            NaN      NaN      NaN            NaN
# 143             NaN            NaN      NaN      NaN            NaN
# 148             NaN            NaN      NaN      NaN   0.000000e+00
# 15              NaN            NaN      NaN      NaN            NaN
# ...             ...            ...      ...      ...            ...
# Ã©videmment     NaN            NaN      NaN      NaN   0.000000e+00
# Ã©vidence       NaN   0.000000e+00      NaN      NaN            NaN
# Ã©vident        NaN            NaN      NaN      NaN   0.000000e+00
# Ã©videntes      NaN            NaN      NaN      NaN            NaN
# Ã©vite          NaN            NaN      NaN      NaN            NaN
# Ã©viter         NaN            NaN      NaN      NaN            NaN
# Ã©vitÃ©         NaN            NaN      NaN      NaN            NaN
# Ã©vitÃ©s        NaN            NaN      NaN      NaN            NaN
# Ã©vocation      NaN            NaN      NaN      NaN            NaN
# Ã©volue         NaN            NaN      NaN      NaN            NaN
# Ã©voluer        NaN            NaN      NaN      NaN   0.000000e+00
# Ã©volution      NaN            NaN      NaN      NaN   0.000000e+00
# Ã©volutions     NaN            NaN      NaN      NaN            NaN
# Ã©voque         NaN            NaN      NaN      NaN            NaN
# Ã©voquer        NaN            NaN      NaN      NaN            NaN
# Ã©voquez        NaN            NaN      NaN      NaN            NaN
# Ã©voquÃ©        NaN            NaN      NaN      NaN            NaN
# Ã©voquÃ©es      NaN            NaN      NaN      NaN   0.000000e+00
# Ã©vÃ©nement     NaN            NaN      NaN      NaN            NaN
# Ã©vÃ©nements    NaN            NaN      NaN      NaN            NaN
# Ãªtes           NaN            NaN      NaN      NaN            NaN
# Ãªtre           NaN   0.000000e+00      NaN      NaN   0.000000e+00
# Ã®les           NaN            NaN      NaN      NaN   0.000000e+00
# Ã´ter           NaN            NaN      NaN      NaN            NaN
# Ã‰carter        NaN            NaN      NaN      NaN            NaN
# Ã‰tant          NaN            NaN      NaN      NaN            NaN
# Ã‰tat           NaN   0.000000e+00      NaN      NaN   0.000000e+00
# Ã‰tats          NaN            NaN      NaN      NaN   0.000000e+00
# Ã‰tats-Unis     NaN   0.000000e+00      NaN      NaN   0.000000e+00
# Ã€              NaN   0.000000e+00      NaN      NaN   0.000000e+00
#
#                   ...         Bruno  anti-competition    Leoni   warned  \
# !                 ...           NaN               NaN      NaN      NaN
# "                 ...           NaN               NaN      NaN      NaN
# %                 ...           NaN               NaN      NaN      NaN
# '                 ...           NaN               NaN      NaN      NaN
# (                 ...           NaN               NaN      NaN      NaN
# )                 ...           NaN               NaN      NaN      NaN
# ,                 ...       0.00000           0.00000  0.00000  0.00000
# -                 ...           NaN               NaN      NaN      NaN
# -1999             ...           NaN               NaN      NaN      NaN
# -20               ...           NaN               NaN      NaN      NaN
# -20ÂºC            ...           NaN               NaN      NaN      NaN
# -40               ...           NaN               NaN      NaN      NaN
# -40Âº             ...           NaN               NaN      NaN      NaN
# .                 ...       0.00000           0.00000  0.00000  0.00000
# ....              ...           NaN               NaN      NaN      NaN
# /                 ...           NaN               NaN      NaN      NaN
# 000               ...           NaN               NaN      NaN      NaN
# 0066              ...           NaN               NaN      NaN      NaN
# 094               ...           NaN               NaN      NaN      NaN
# 1                 ...           NaN               NaN      NaN      NaN
# 1,2               ...           NaN               NaN      NaN      NaN
# 10                ...           NaN               NaN      NaN      NaN
# 101               ...           NaN               NaN      NaN      NaN
# 11                ...           NaN               NaN      NaN      NaN
# 110               ...           NaN               NaN      NaN      NaN
# 12                ...           NaN               NaN      NaN      NaN
# 13                ...           NaN               NaN      NaN      NaN
# 143               ...           NaN               NaN      NaN      NaN
# 148               ...           NaN               NaN      NaN      NaN
# 15                ...           NaN               NaN      NaN      NaN
# ...               ...           ...               ...      ...      ...
# Ã©videmment       ...           NaN               NaN      NaN      NaN
# Ã©vidence         ...           NaN               NaN      NaN      NaN
# Ã©vident          ...           NaN               NaN      NaN      NaN
# Ã©videntes        ...           NaN               NaN      NaN      NaN
# Ã©vite            ...           NaN               NaN      NaN      NaN
# Ã©viter           ...           NaN               NaN      NaN      NaN
# Ã©vitÃ©           ...           NaN               NaN      NaN      NaN
# Ã©vitÃ©s          ...           NaN               NaN      NaN      NaN
# Ã©vocation        ...           NaN               NaN      NaN      NaN
# Ã©volue           ...           NaN               NaN      NaN      NaN
# Ã©voluer          ...           NaN               NaN      NaN      NaN
# Ã©volution        ...           NaN               NaN      NaN      NaN
# Ã©volutions       ...           NaN               NaN      NaN      NaN
# Ã©voque           ...           NaN               NaN      NaN      NaN
# Ã©voquer          ...           NaN               NaN      NaN      NaN
# Ã©voquez          ...           NaN               NaN      NaN      NaN
# Ã©voquÃ©          ...           NaN               NaN      NaN      NaN
# Ã©voquÃ©es        ...           NaN               NaN      NaN      NaN
# Ã©vÃ©nement       ...           NaN               NaN      NaN      NaN
# Ã©vÃ©nements      ...           NaN               NaN      NaN      NaN
# Ãªtes             ...           NaN               NaN      NaN      NaN
# Ãªtre             ...           NaN               NaN      NaN      NaN
# Ã®les             ...           NaN               NaN      NaN      NaN
# Ã´ter             ...           NaN               NaN      NaN      NaN
# Ã‰carter          ...           NaN               NaN      NaN      NaN
# Ã‰tant            ...           NaN               NaN      NaN      NaN
# Ã‰tat             ...           NaN               NaN      NaN      NaN
# Ã‰tats            ...           NaN               NaN      NaN      NaN
# Ã‰tats-Unis       ...           NaN               NaN      NaN      NaN
# Ã€                ...       0.04654           0.04654  0.04654  0.04654
#
#                  heed    Eieck     users  hindrances    choice  interference
# !                 NaN      NaN       NaN         NaN       NaN           NaN
# "                 NaN      NaN       NaN         NaN       NaN           NaN
# %                 NaN      NaN       NaN         NaN       NaN           NaN
# '                 NaN      NaN       NaN         NaN       NaN           NaN
# (                 NaN      NaN       NaN         NaN       NaN           NaN
# )                 NaN      NaN       NaN         NaN       NaN           NaN
# ,             0.00000  0.00000  0.000000    0.000000  0.000000      0.000000
# -                 NaN      NaN       NaN         NaN       NaN           NaN
# -1999             NaN      NaN       NaN         NaN       NaN           NaN
# -20               NaN      NaN       NaN         NaN       NaN           NaN
# -20ÂºC            NaN      NaN       NaN         NaN       NaN           NaN
# -40               NaN      NaN       NaN         NaN       NaN           NaN
# -40Âº             NaN      NaN       NaN         NaN       NaN           NaN
# .             0.00000  0.00000  0.000000    0.000000  0.000000      0.000000
# ....              NaN      NaN       NaN         NaN       NaN           NaN
# /                 NaN      NaN       NaN         NaN       NaN           NaN
# 000               NaN      NaN       NaN         NaN       NaN           NaN
# 0066              NaN      NaN       NaN         NaN       NaN           NaN
# 094               NaN      NaN       NaN         NaN       NaN           NaN
# 1                 NaN      NaN       NaN         NaN       NaN           NaN
# 1,2               NaN      NaN       NaN         NaN       NaN           NaN
# 10                NaN      NaN       NaN         NaN       NaN           NaN
# 101               NaN      NaN       NaN         NaN       NaN           NaN
# 11                NaN      NaN       NaN         NaN       NaN           NaN
# 110               NaN      NaN       NaN         NaN       NaN           NaN
# 12                NaN      NaN       NaN         NaN       NaN           NaN
# 13                NaN      NaN       NaN         NaN       NaN           NaN
# 143               NaN      NaN       NaN         NaN       NaN           NaN
# 148               NaN      NaN       NaN         NaN       NaN           NaN
# 15                NaN      NaN       NaN         NaN       NaN           NaN
# ...               ...      ...       ...         ...       ...           ...
# Ã©videmment       NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vidence         NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vident          NaN      NaN       NaN         NaN       NaN           NaN
# Ã©videntes        NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vite            NaN      NaN       NaN         NaN       NaN           NaN
# Ã©viter           NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vitÃ©           NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vitÃ©s          NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vocation        NaN      NaN       NaN         NaN       NaN           NaN
# Ã©volue           NaN      NaN       NaN         NaN       NaN           NaN
# Ã©voluer          NaN      NaN       NaN         NaN       NaN           NaN
# Ã©volution        NaN      NaN       NaN         NaN       NaN           NaN
# Ã©volutions       NaN      NaN       NaN         NaN       NaN           NaN
# Ã©voque           NaN      NaN       NaN         NaN       NaN           NaN
# Ã©voquer          NaN      NaN       NaN         NaN       NaN           NaN
# Ã©voquez          NaN      NaN       NaN         NaN       NaN           NaN
# Ã©voquÃ©          NaN      NaN       NaN         NaN       NaN           NaN
# Ã©voquÃ©es        NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vÃ©nement       NaN      NaN       NaN         NaN       NaN           NaN
# Ã©vÃ©nements      NaN      NaN       NaN         NaN       NaN           NaN
# Ãªtes             NaN      NaN       NaN         NaN       NaN           NaN
# Ãªtre             NaN      NaN       NaN         NaN       NaN           NaN
# Ã®les             NaN      NaN       NaN         NaN       NaN           NaN
# Ã´ter             NaN      NaN       NaN         NaN       NaN           NaN
# Ã‰carter          NaN      NaN       NaN         NaN       NaN           NaN
# Ã‰tant            NaN      NaN       NaN         NaN       NaN           NaN
# Ã‰tat             NaN      NaN  0.076097    0.076097  0.076097      0.076097
# Ã‰tats            NaN      NaN       NaN         NaN       NaN           NaN
# Ã‰tats-Unis       NaN      NaN       NaN         NaN       NaN           NaN
# Ã€            0.04654  0.04654       NaN         NaN       NaN           NaN
#
# [4296 rows x 3620 columns]

# %% [markdown]
# Problem 2: Initialize IBM model 1

# %%
# IBM model 1
def model1(source_corpus, foreign_corpus, t):
    for s in range(0, 1000):
        count = defaultdict(int)
        count_e = defaultdict(int)
        for e_line, f_line in zip(open(source_corpus), open(foreign_corpus)):
            # Go over words in f, e
            for f in list(f_line.strip().split(" ")):
                # include NULL for possible source alignments
                e_list = list(e_line.strip().split(" "))
                e_list.append('NULL')
                # Calculate sum first
                sum_e = 0
                for e in e_list:
                    sum_e += t[e][f]
                for e in e_list:
                    # Update rule
                    count[(f,e)] += (t[e][f] / float(sum_e))
                    count_e[e] += (t[e][f] / float(sum_e))
        # Update t values
        for (f,e) in count.keys():
            t[e][f] = float(count[(f,e)]) / float(count_e[e])
    return t

# %%
#Find alignments for the first 20 sentence pairs in the training data, save to output file
def model_alignments_fr_en(t):
    source = open("fr-en.en", "r")
    foreign = open("fr-en.fr", "r")
    Align = open("Align", "w")
    for j in range(0,20):
        line_e = source.readline().strip()
        line_f = foreign.readline().strip()
        alignments = []
        for f in range(0, len(line_f.split(" "))):
            alignment = 0;
            probability = 0;
            for e in range(0, len(line_e.split(" "))):
                p = t[line_e.split(" ")[e]][line_f.split(" ")[f]]
                if probability < p:
                    probability = p
                    alignment = e+1
            # Check NULL alignment
            if probability < t["NULL"][line_f.split(" ")[f]]:
                probability = t["NULL"][line_f.split(" ")[f]]
                alignment = 0
            alignments.append(alignment)
        print(line_e, file=Align)
        print(line_f, file=Align)
        print(alignments, file=Align)
        print("", file=Align)
    source.close()
    foreign.close()
    Align.close()

# %%
def main():
    start_time = time.time()
    #Read in corpus, initialize t(f|e) for each unique English word-foreign word combo
    t = init_t("fr-en.en","fr-en.fr")
    #Run  5 iterations of the EM algorithm for IBM model 1
    model1("fr-en.en","fr-en.fr",t)
    #Find alignments for the first 20 sentence pairs in the training data, save to output
    model_alignments_fr_en(t)
    logging.warning("--- %s seconds ---" % (time.time() - start_time))

if __name__ == '__main__':     # if the function is the main function ...
    main()
# Out:
# WARNING:root:--- 2253.500406265259 seconds ---

# %%
file = open('Align','r') 
print(file.read())
# Out:
# Resumption of the session
# Reprise de la session
# [1, 2, 3, 4]
#
# I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999 , and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
# Je dÃ©clare reprise la session du Parlement europÃ©en qui avait Ã©tÃ© interrompue le vendredi 17 dÃ©cembre dernier et je vous renouvelle tous mes vux en espÃ©rant que vous avez passÃ© de bonnes vacances .
# [1, 2, 2, 4, 5, 11, 9, 8, 22, 2, 13, 2, 4, 12, 13, 14, 12, 17, 1, 25, 2, 2, 2, 27, 24, 2, 33, 25, 2, 2, 6, 2, 2, 40]
#
# Although , as you will have seen , the dreaded ' millennium bug ' failed to materialise , still the people in a number of countries suffered a series of natural disasters that truly were dreadful .
# Comme vous avez pu le constater , le grand " bogue de l' an 2000 " ne s' est pas produit . En revanche , les citoyens d' un certain nombre de nos pays ont Ã©tÃ© victimes de catastrophes naturelles qui ont vraiment Ã©tÃ© terribles .
# [10, 4, 10, 10, 15, 10, 2, 15, 10, 10, 10, 11, 3, 10, 10, 10, 17, 12, 34, 15, 10, 37, 10, 10, 2, 21, 10, 25, 23, 10, 24, 11, 17, 26, 27, 35, 10, 11, 32, 31, 7, 27, 34, 35, 27, 37]
#
# You have requested a debate on this subject in the course of the next few days , during this part-session .
# Vous avez souhaitÃ© un dÃ©bat Ã  ce sujet dans les prochains jours , au cours de cette pÃ©riode de session .
# [1, 1, 16, 4, 5, 7, 7, 16, 9, 2, 16, 16, 17, 11, 18, 12, 3, 18, 12, 20, 21]
#
# In the meantime , I should like to observe a minute ' s silence , as a number of Members have requested , on behalf of all the victims concerned , particularly those of the terrible storms , in the various countries of the European Union .
# En attendant , je souhaiterais , comme un certain nombre de collÃ¨gues me l' ont demandÃ© , que nous observions une minute de silence pour toutes les victimes , des tempÃªtes notamment , dans les diffÃ©rents pays de l' Union europÃ©enne qui ont Ã©tÃ© touchÃ©s .
# [1, 3, 4, 5, 3, 4, 16, 10, 3, 18, 12, 20, 3, 16, 21, 22, 4, 16, 36, 3, 10, 11, 12, 14, 14, 3, 41, 3, 4, 30, 37, 32, 4, 39, 41, 41, 42, 12, 16, 46, 45, 33, 21, 36, 37, 47]
#
# Please rise , then , for this minute ' s silence .
# Je vous invite Ã  vous lever pour cette minute de silence .
# [1, 1, 2, 4, 1, 2, 6, 2, 8, 9, 11, 12]
#
# ( The House rose and observed a minute ' s silence )
# ( Le Parlement , debout , observe une minute de silence )
# [1, 2, 3, 4, 4, 4, 4, 7, 8, 9, 11, 12]
#
# Madam President , on a point of order .
# Madame la PrÃ©sidente , c' est une motion de procÃ©dure .
# [1, 4, 1, 3, 8, 8, 5, 8, 7, 8, 9]
#
# You will be aware from the press and television that there have been a number of bomb explosions and killings in Sri Lanka .
# Vous avez probablement appris par la presse et par la tÃ©lÃ©vision que plusieurs attentats Ã  la bombe et crimes ont Ã©tÃ© perpÃ©trÃ©s au Sri Lanka .
# [1, 1, 17, 17, 17, 6, 7, 8, 17, 6, 9, 10, 15, 17, 4, 6, 17, 8, 17, 12, 13, 17, 23, 23, 23, 24]
#
# One of the people assassinated very recently in Sri Lanka was Mr Kumar Ponnambalam , who had visited the European Parliament just a few months ago .
# L' une des personnes qui vient d' Ãªtre assassinÃ©e au Sri Lanka est M. Kumar Ponnambalam , qui avait rendu visite au Parlement europÃ©en il y a quelques mois Ã  peine .
# [5, 23, 17, 4, 16, 5, 17, 5, 5, 10, 10, 10, 1, 12, 5, 9, 15, 16, 5, 5, 5, 10, 21, 20, 26, 26, 11, 24, 25, 22, 5, 27]
#
# Would it be appropriate for you , Madam President , to write a letter to the Sri Lankan President expressing Parliament 's regret at his and the other violent deaths in Sri Lanka and urging her to do everything she possibly can to seek a peaceful reconciliation to a very difficult situation ?
# Ne pensez-vous pas , Madame la PrÃ©sidente , qu' il conviendrait d' Ã©crire une lettre au prÃ©sident du Sri Lanka pour lui communiquer que le Parlement dÃ©plore les morts violentes , dont celle de M. Ponnambalam , et pour l' inviter instamment Ã  faire tout ce qui est en son pouvoir pour chercher une rÃ©conciliation pacifique et mettre un terme Ã  cette situation particuliÃ¨rement difficile .
# [1, 1, 38, 7, 8, 16, 8, 7, 4, 2, 1, 28, 1, 13, 14, 33, 1, 22, 33, 33, 5, 1, 1, 40, 9, 21, 23, 3, 1, 1, 7, 20, 1, 11, 35, 17, 7, 26, 5, 22, 1, 1, 24, 38, 39, 20, 22, 17, 36, 25, 1, 5, 44, 13, 1, 1, 26, 1, 13, 1, 24, 41, 52, 1, 51, 0]
#
# Yes , Mr Evans , I feel an initiative of the type you have just suggested would be entirely appropriate .
# Oui , Monsieur Evans , je pense qu' une initiative dans le sens que vous venez de suggÃ©rer serait tout Ã  fait appropriÃ©e .
# [1, 2, 3, 4, 2, 6, 19, 7, 8, 9, 9, 11, 19, 12, 13, 19, 10, 19, 20, 15, 15, 16, 19, 21]
#
# If the House agrees , I shall do as Mr Evans has suggested .
# Si l' AssemblÃ©e en est d' accord , je ferai comme M. Evans l' a suggÃ©rÃ© .
# [1, 9, 3, 13, 4, 4, 4, 5, 6, 13, 9, 10, 11, 9, 12, 13, 14]
#
# Madam President , on a point of order .
# Madame la PrÃ©sidente , c' est une motion de procÃ©dure .
# [1, 4, 1, 3, 8, 8, 5, 8, 7, 8, 9]
#
# I would like your advice about Rule 143 concerning inadmissibility .
# Je voudrais vous demander un conseil au sujet de l' article 143 , qui concerne l' irrecevabilitÃ© .
# [1, 3, 5, 5, 5, 5, 5, 5, 6, 6, 7, 5, 7, 5, 5, 6, 5, 11]
#
# My question relates to something that will come up on Thursday and which I will then raise again .
# Ma question porte sur un sujet qui est Ã  l' ordre du jour du jeudi et que je soulÃ¨verai donc une nouvelle fois .
# [17, 2, 5, 10, 1, 2, 13, 8, 4, 5, 17, 3, 17, 3, 11, 12, 6, 14, 17, 17, 5, 17, 18, 19]
#
# The Cunha report on multiannual guidance programmes comes before Parliament on Thursday and contains a proposal in paragraph 6 that a form of quota penalties should be introduced for countries which fail to meet their fleet reduction targets annually .
# Le paragraphe 6 du rapport Cunha sur les programmes d' orientation pluriannuels , qui sera soumis au Parlement ce jeudi , propose d' introduire des sanctions applicables aux pays qui ne respectent pas les objectifs annuels de rÃ©duction de leur flotte .
# [1, 2, 2, 4, 3, 2, 4, 28, 7, 6, 6, 2, 26, 31, 2, 34, 9, 10, 32, 12, 26, 2, 6, 2, 23, 25, 2, 2, 30, 31, 2, 2, 2, 28, 2, 2, 23, 37, 23, 35, 2, 40]
#
# It says that this should be done despite the principle of relative stability .
# Il prÃ©cise que cela devrait Ãªtre fait malgrÃ© le principe de stabilitÃ© relative .
# [1, 2, 3, 2, 2, 2, 7, 8, 13, 10, 11, 13, 12, 14]
#
# I believe that the principle of relative stability is a fundamental legal principle of the common fisheries policy and a proposal to subvert it would be legally inadmissible .
# Ã€ mon sens , le principe de stabilitÃ© relative est un principe juridique fondamental de la politique commune de la pÃªche et toute proposition le bouleversant serait juridiquement irrecevable .
# [23, 23, 23, 25, 8, 5, 6, 8, 7, 9, 10, 5, 12, 23, 6, 4, 18, 16, 6, 4, 17, 19, 7, 21, 8, 23, 23, 23, 23, 29]
#
# I want to know whether one can raise an objection of that kind to what is merely a report , not a legislative proposal , and whether that is something I can competently do on Thursday .
# Je voudrais savoir si l' on peut avancer une objection de ce type Ã  ce qui n' est qu' un rapport , pas une proposition lÃ©gislative , et si je suis habilitÃ© Ã  le faire ce jeudi .
# [1, 10, 4, 5, 6, 13, 7, 10, 9, 10, 11, 15, 10, 3, 15, 13, 4, 16, 5, 18, 19, 20, 21, 9, 24, 23, 20, 26, 5, 1, 10, 10, 3, 34, 34, 15, 36, 37]

# %% [markdown]
# Problem 3: German to english Model

# %%
t = init_t("de-en.en","de-en.de")
Prob1 = pd.DataFrame(t)
Prob1
# Out:
#                              of       the  Resumption      NULL   session  \
# !                      0.000218  0.000218         NaN  0.000218       NaN
# "                      0.000218  0.000218         NaN  0.000218       NaN
# %                      0.000218  0.000218         NaN  0.000218       NaN
# (                      0.000218  0.000218         NaN  0.000218       NaN
# )                      0.000218  0.000218         NaN  0.000218       NaN
# ,                      0.000218  0.000218         NaN  0.000218  0.000218
# -                      0.000218  0.000218         NaN  0.000218       NaN
# -20                         NaN  0.000218         NaN  0.000218       NaN
# -40                         NaN  0.000218         NaN  0.000218       NaN
# -garantien             0.000218       NaN         NaN  0.000218       NaN
# .                      0.000218  0.000218         NaN  0.000218  0.000218
# ...                    0.000218  0.000218         NaN  0.000218       NaN
# /                      0.000218  0.000218         NaN  0.000218       NaN
# 000                    0.000218  0.000218         NaN  0.000218       NaN
# 0066                   0.000218  0.000218         NaN  0.000218       NaN
# 1                      0.000218  0.000218         NaN  0.000218       NaN
# 1,2                    0.000218  0.000218         NaN  0.000218       NaN
# 1-Gebiet               0.000218  0.000218         NaN  0.000218       NaN
# 1-Regionen             0.000218  0.000218         NaN  0.000218       NaN
# 1.                     0.000218  0.000218         NaN  0.000218       NaN
# 10                     0.000218  0.000218         NaN  0.000218       NaN
# 101                    0.000218  0.000218         NaN  0.000218       NaN
# 11                     0.000218  0.000218         NaN  0.000218       NaN
# 110                    0.000218  0.000218         NaN  0.000218       NaN
# 12.00                       NaN       NaN         NaN  0.000218       NaN
# 13.                    0.000218  0.000218         NaN  0.000218       NaN
# 143                         NaN       NaN         NaN  0.000218       NaN
# 148                    0.000218  0.000218         NaN  0.000218       NaN
# 15                     0.000218  0.000218         NaN  0.000218       NaN
# 15.                    0.000218  0.000218         NaN  0.000218       NaN
# ...                         ...       ...         ...       ...       ...
# Ã¼blich                     NaN  0.000218         NaN  0.000218       NaN
# Ã¼brigen               0.000218  0.000218         NaN  0.000218       NaN
# Ã¼brigens              0.000218  0.000218         NaN  0.000218       NaN
# Ãœber                  0.000218  0.000218         NaN  0.000218       NaN
# Ãœbereinkommen         0.000218  0.000218         NaN  0.000218       NaN
# Ãœbereinstimmung       0.000218  0.000218         NaN  0.000218       NaN
# Ãœbergangsphase        0.000218       NaN         NaN  0.000218       NaN
# Ãœbergangsregeln       0.000218  0.000218         NaN  0.000218       NaN
# Ãœbergreifende         0.000218  0.000218         NaN  0.000218       NaN
# Ãœberlastung           0.000218  0.000218         NaN  0.000218       NaN
# Ãœberlegungen               NaN  0.000218         NaN  0.000218       NaN
# Ãœbernahmen            0.000218  0.000218         NaN  0.000218       NaN
# ÃœberprÃ¼fung          0.000218  0.000218         NaN  0.000218       NaN
# Ãœberwindung           0.000218  0.000218         NaN  0.000218       NaN
# Ãœbung                 0.000218  0.000218         NaN  0.000218       NaN
# Ã–ffentliche                NaN  0.000218         NaN  0.000218       NaN
# Ã–ffentlichkeit        0.000218  0.000218         NaN  0.000218       NaN
# Ã–ffnung               0.000218  0.000218         NaN  0.000218       NaN
# Ã–lpest                     NaN  0.000218         NaN  0.000218       NaN
# Ã–sterreich            0.000218  0.000218         NaN  0.000218       NaN
# Ã–sterreicher          0.000218  0.000218         NaN  0.000218       NaN
# Ã–sterreichs           0.000218  0.000218         NaN  0.000218       NaN
# Ã„nderung              0.000218  0.000218         NaN  0.000218       NaN
# Ã„nderungen            0.000218  0.000218         NaN  0.000218       NaN
# Ã„nderungsantrag       0.000218  0.000218         NaN  0.000218       NaN
# Ã„nderungsantrÃ¤ge     0.000218  0.000218         NaN  0.000218       NaN
# Ã„nderungsantrÃ¤gen    0.000218  0.000218         NaN  0.000218       NaN
# Ã„nderungsvorschlag         NaN  0.000218         NaN  0.000218       NaN
# Ã„nderungsvorschlÃ¤ge  0.000218  0.000218         NaN  0.000218       NaN
# Ã„rgernis                   NaN       NaN         NaN  0.000218       NaN
#
#                           happy      year   festive   resumed  European  \
# !                      0.000218  0.000218       NaN       NaN  0.000218
# "                           NaN       NaN       NaN       NaN  0.000218
# %                           NaN  0.000218       NaN       NaN  0.000218
# (                           NaN       NaN       NaN       NaN  0.000218
# )                           NaN       NaN       NaN       NaN  0.000218
# ,                      0.000218  0.000218  0.000218  0.000218  0.000218
# -                           NaN  0.000218       NaN       NaN  0.000218
# -20                         NaN       NaN       NaN       NaN       NaN
# -40                         NaN       NaN       NaN       NaN       NaN
# -garantien                  NaN       NaN       NaN       NaN       NaN
# .                      0.000218  0.000218  0.000218  0.000218  0.000218
# ...                         NaN       NaN       NaN       NaN       NaN
# /                           NaN       NaN       NaN       NaN  0.000218
# 000                         NaN       NaN       NaN       NaN       NaN
# 0066                        NaN       NaN       NaN       NaN  0.000218
# 1                           NaN       NaN       NaN       NaN       NaN
# 1,2                         NaN  0.000218       NaN       NaN       NaN
# 1-Gebiet                    NaN       NaN       NaN       NaN       NaN
# 1-Regionen                  NaN       NaN       NaN       NaN       NaN
# 1.                          NaN  0.000218       NaN       NaN  0.000218
# 10                          NaN       NaN       NaN       NaN       NaN
# 101                         NaN       NaN       NaN       NaN       NaN
# 11                          NaN       NaN       NaN       NaN       NaN
# 110                         NaN       NaN       NaN       NaN       NaN
# 12.00                       NaN       NaN       NaN       NaN       NaN
# 13.                         NaN       NaN       NaN       NaN       NaN
# 143                         NaN       NaN       NaN       NaN       NaN
# 148                         NaN       NaN       NaN       NaN  0.000218
# 15                          NaN       NaN       NaN       NaN       NaN
# 15.                         NaN       NaN       NaN       NaN       NaN
# ...                         ...       ...       ...       ...       ...
# Ã¼blich                     NaN       NaN       NaN       NaN       NaN
# Ã¼brigen                    NaN       NaN       NaN       NaN  0.000218
# Ã¼brigens                   NaN       NaN       NaN       NaN       NaN
# Ãœber                       NaN       NaN       NaN       NaN       NaN
# Ãœbereinkommen              NaN       NaN       NaN       NaN  0.000218
# Ãœbereinstimmung            NaN       NaN       NaN       NaN       NaN
# Ãœbergangsphase             NaN       NaN       NaN       NaN       NaN
# Ãœbergangsregeln            NaN       NaN       NaN       NaN       NaN
# Ãœbergreifende              NaN       NaN       NaN       NaN       NaN
# Ãœberlastung                NaN       NaN       NaN       NaN       NaN
# Ãœberlegungen               NaN       NaN       NaN       NaN       NaN
# Ãœbernahmen                 NaN       NaN       NaN       NaN       NaN
# ÃœberprÃ¼fung               NaN       NaN       NaN       NaN       NaN
# Ãœberwindung                NaN       NaN       NaN       NaN  0.000218
# Ãœbung                      NaN       NaN       NaN       NaN       NaN
# Ã–ffentliche                NaN       NaN       NaN       NaN       NaN
# Ã–ffentlichkeit             NaN       NaN       NaN       NaN       NaN
# Ã–ffnung                    NaN       NaN       NaN       NaN       NaN
# Ã–lpest                     NaN       NaN       NaN       NaN       NaN
# Ã–sterreich                 NaN       NaN       NaN       NaN       NaN
# Ã–sterreicher               NaN  0.000218       NaN       NaN       NaN
# Ã–sterreichs                NaN       NaN       NaN       NaN       NaN
# Ã„nderung                   NaN       NaN       NaN       NaN       NaN
# Ã„nderungen                 NaN       NaN       NaN       NaN  0.000218
# Ã„nderungsantrag            NaN       NaN       NaN       NaN  0.000218
# Ã„nderungsantrÃ¤ge          NaN       NaN       NaN       NaN  0.000218
# Ã„nderungsantrÃ¤gen         NaN       NaN       NaN       NaN       NaN
# Ã„nderungsvorschlag         NaN       NaN       NaN       NaN       NaN
# Ã„nderungsvorschlÃ¤ge       NaN       NaN       NaN       NaN       NaN
# Ã„rgernis                   NaN       NaN       NaN       NaN       NaN
#
#                          ...     judiciary  Directorate-General      load  \
# !                        ...           NaN                  NaN       NaN
# "                        ...           NaN                  NaN       NaN
# %                        ...           NaN                  NaN       NaN
# (                        ...           NaN                  NaN       NaN
# )                        ...           NaN                  NaN       NaN
# ,                        ...      0.000218             0.000218  0.000218
# -                        ...           NaN                  NaN       NaN
# -20                      ...           NaN                  NaN       NaN
# -40                      ...           NaN                  NaN       NaN
# -garantien               ...           NaN                  NaN       NaN
# .                        ...      0.000218             0.000218  0.000218
# ...                      ...           NaN                  NaN       NaN
# /                        ...           NaN                  NaN       NaN
# 000                      ...           NaN                  NaN       NaN
# 0066                     ...           NaN                  NaN       NaN
# 1                        ...           NaN                  NaN       NaN
# 1,2                      ...           NaN                  NaN       NaN
# 1-Gebiet                 ...           NaN                  NaN       NaN
# 1-Regionen               ...           NaN                  NaN       NaN
# 1.                       ...           NaN                  NaN       NaN
# 10                       ...           NaN                  NaN       NaN
# 101                      ...           NaN                  NaN       NaN
# 11                       ...           NaN                  NaN       NaN
# 110                      ...           NaN                  NaN       NaN
# 12.00                    ...           NaN                  NaN       NaN
# 13.                      ...           NaN                  NaN       NaN
# 143                      ...           NaN                  NaN       NaN
# 148                      ...           NaN                  NaN       NaN
# 15                       ...           NaN                  NaN       NaN
# 15.                      ...           NaN                  NaN       NaN
# ...                      ...           ...                  ...       ...
# Ã¼blich                  ...           NaN                  NaN       NaN
# Ã¼brigen                 ...           NaN                  NaN       NaN
# Ã¼brigens                ...           NaN                  NaN       NaN
# Ãœber                    ...           NaN                  NaN       NaN
# Ãœbereinkommen           ...           NaN                  NaN       NaN
# Ãœbereinstimmung         ...           NaN                  NaN       NaN
# Ãœbergangsphase          ...           NaN                  NaN       NaN
# Ãœbergangsregeln         ...           NaN                  NaN       NaN
# Ãœbergreifende           ...           NaN                  NaN       NaN
# Ãœberlastung             ...      0.000218             0.000218  0.000218
# Ãœberlegungen            ...           NaN                  NaN       NaN
# Ãœbernahmen              ...           NaN                  NaN       NaN
# ÃœberprÃ¼fung            ...           NaN                  NaN       NaN
# Ãœberwindung             ...           NaN                  NaN       NaN
# Ãœbung                   ...           NaN                  NaN       NaN
# Ã–ffentliche             ...           NaN                  NaN       NaN
# Ã–ffentlichkeit          ...           NaN                  NaN       NaN
# Ã–ffnung                 ...           NaN                  NaN       NaN
# Ã–lpest                  ...           NaN                  NaN       NaN
# Ã–sterreich              ...           NaN                  NaN       NaN
# Ã–sterreicher            ...           NaN                  NaN       NaN
# Ã–sterreichs             ...           NaN                  NaN       NaN
# Ã„nderung                ...           NaN                  NaN       NaN
# Ã„nderungen              ...           NaN                  NaN       NaN
# Ã„nderungsantrag         ...           NaN                  NaN       NaN
# Ã„nderungsantrÃ¤ge       ...           NaN                  NaN       NaN
# Ã„nderungsantrÃ¤gen      ...           NaN                  NaN       NaN
# Ã„nderungsvorschlag      ...           NaN                  NaN       NaN
# Ã„nderungsvorschlÃ¤ge    ...           NaN                  NaN       NaN
# Ã„rgernis                ...           NaN                  NaN       NaN
#
#                            plea  decrease    judges      Does  pressure  \
# !                           NaN       NaN       NaN       NaN       NaN
# "                           NaN       NaN       NaN       NaN       NaN
# %                           NaN       NaN       NaN       NaN       NaN
# (                           NaN       NaN       NaN       NaN       NaN
# )                           NaN       NaN       NaN       NaN       NaN
# ,                      0.000218  0.000218  0.000218  0.000218  0.000218
# -                           NaN       NaN       NaN       NaN       NaN
# -20                         NaN       NaN       NaN       NaN       NaN
# -40                         NaN       NaN       NaN       NaN       NaN
# -garantien                  NaN       NaN       NaN       NaN       NaN
# .                      0.000218       NaN       NaN       NaN       NaN
# ...                         NaN       NaN       NaN       NaN       NaN
# /                           NaN       NaN       NaN       NaN       NaN
# 000                         NaN       NaN       NaN       NaN       NaN
# 0066                        NaN       NaN       NaN       NaN       NaN
# 1                           NaN       NaN       NaN       NaN       NaN
# 1,2                         NaN       NaN       NaN       NaN       NaN
# 1-Gebiet                    NaN       NaN       NaN       NaN       NaN
# 1-Regionen                  NaN       NaN       NaN       NaN       NaN
# 1.                          NaN       NaN       NaN       NaN       NaN
# 10                          NaN       NaN       NaN       NaN       NaN
# 101                         NaN       NaN       NaN       NaN       NaN
# 11                          NaN       NaN       NaN       NaN       NaN
# 110                         NaN       NaN       NaN       NaN       NaN
# 12.00                       NaN       NaN       NaN       NaN       NaN
# 13.                         NaN       NaN       NaN       NaN       NaN
# 143                         NaN       NaN       NaN       NaN       NaN
# 148                         NaN       NaN       NaN       NaN       NaN
# 15                          NaN       NaN       NaN       NaN       NaN
# 15.                         NaN       NaN       NaN       NaN       NaN
# ...                         ...       ...       ...       ...       ...
# Ã¼blich                     NaN       NaN       NaN       NaN       NaN
# Ã¼brigen                    NaN       NaN       NaN       NaN       NaN
# Ã¼brigens                   NaN       NaN       NaN       NaN       NaN
# Ãœber                       NaN       NaN       NaN       NaN       NaN
# Ãœbereinkommen              NaN       NaN       NaN       NaN       NaN
# Ãœbereinstimmung            NaN       NaN       NaN       NaN       NaN
# Ãœbergangsphase             NaN       NaN       NaN       NaN       NaN
# Ãœbergangsregeln            NaN       NaN       NaN       NaN       NaN
# Ãœbergreifende              NaN       NaN       NaN       NaN       NaN
# Ãœberlastung           0.000218       NaN       NaN       NaN       NaN
# Ãœberlegungen               NaN       NaN       NaN       NaN       NaN
# Ãœbernahmen                 NaN       NaN       NaN       NaN       NaN
# ÃœberprÃ¼fung               NaN       NaN       NaN       NaN       NaN
# Ãœberwindung                NaN       NaN       NaN       NaN       NaN
# Ãœbung                      NaN       NaN       NaN       NaN       NaN
# Ã–ffentliche                NaN       NaN       NaN       NaN       NaN
# Ã–ffentlichkeit             NaN       NaN       NaN       NaN       NaN
# Ã–ffnung                    NaN       NaN       NaN       NaN       NaN
# Ã–lpest                     NaN       NaN       NaN       NaN       NaN
# Ã–sterreich                 NaN       NaN       NaN       NaN       NaN
# Ã–sterreicher               NaN       NaN       NaN       NaN       NaN
# Ã–sterreichs                NaN       NaN       NaN       NaN       NaN
# Ã„nderung                   NaN       NaN       NaN       NaN       NaN
# Ã„nderungen                 NaN       NaN       NaN       NaN       NaN
# Ã„nderungsantrag            NaN       NaN       NaN       NaN       NaN
# Ã„nderungsantrÃ¤ge          NaN       NaN       NaN       NaN       NaN
# Ã„nderungsantrÃ¤gen         NaN       NaN       NaN       NaN       NaN
# Ã„nderungsvorschlag         NaN       NaN       NaN       NaN       NaN
# Ã„nderungsvorschlÃ¤ge       NaN       NaN       NaN       NaN       NaN
# Ã„rgernis                   NaN       NaN       NaN       NaN       NaN
#
#                        reactions   authors
# !                            NaN       NaN
# "                            NaN       NaN
# %                            NaN       NaN
# (                            NaN       NaN
# )                            NaN       NaN
# ,                            NaN       NaN
# -                            NaN       NaN
# -20                          NaN       NaN
# -40                          NaN       NaN
# -garantien                   NaN       NaN
# .                       0.000218  0.000218
# ...                          NaN       NaN
# /                            NaN       NaN
# 000                          NaN       NaN
# 0066                         NaN       NaN
# 1                            NaN       NaN
# 1,2                          NaN       NaN
# 1-Gebiet                     NaN       NaN
# 1-Regionen                   NaN       NaN
# 1.                           NaN       NaN
# 10                           NaN       NaN
# 101                          NaN       NaN
# 11                           NaN       NaN
# 110                          NaN       NaN
# 12.00                        NaN       NaN
# 13.                          NaN       NaN
# 143                          NaN       NaN
# 148                          NaN       NaN
# 15                           NaN       NaN
# 15.                          NaN       NaN
# ...                          ...       ...
# Ã¼blich                      NaN       NaN
# Ã¼brigen                     NaN       NaN
# Ã¼brigens                    NaN       NaN
# Ãœber                        NaN       NaN
# Ãœbereinkommen               NaN       NaN
# Ãœbereinstimmung             NaN       NaN
# Ãœbergangsphase              NaN       NaN
# Ãœbergangsregeln             NaN       NaN
# Ãœbergreifende               NaN       NaN
# Ãœberlastung                 NaN       NaN
# Ãœberlegungen                NaN       NaN
# Ãœbernahmen                  NaN       NaN
# ÃœberprÃ¼fung                NaN       NaN
# Ãœberwindung                 NaN       NaN
# Ãœbung                       NaN       NaN
# Ã–ffentliche                 NaN       NaN
# Ã–ffentlichkeit              NaN       NaN
# Ã–ffnung                     NaN       NaN
# Ã–lpest                      NaN       NaN
# Ã–sterreich                  NaN       NaN
# Ã–sterreicher                NaN       NaN
# Ã–sterreichs                 NaN       NaN
# Ã„nderung                    NaN       NaN
# Ã„nderungen                  NaN       NaN
# Ã„nderungsantrag             NaN       NaN
# Ã„nderungsantrÃ¤ge           NaN       NaN
# Ã„nderungsantrÃ¤gen          NaN       NaN
# Ã„nderungsvorschlag          NaN       NaN
# Ã„nderungsvorschlÃ¤ge        NaN       NaN
# Ã„rgernis                    NaN       NaN
#
# [4804 rows x 3621 columns]

# %%
# Define model alignment for German -ENglish corpus and save file
def model_alignments_Ge_en(t):
    source = open("de-en.en", "r")
    foreign = open("de-en.de", "r")
    Align_G = open("Align-German", "w")
    for j in range(0,20):
        line_e = source.readline().strip()
        line_f = foreign.readline().strip()
        alignments = []
        for f in range(0, len(line_f.split(" "))):
            alignment = 0;
            probability = 0;
            for e in range(0, len(line_e.split(" "))):
                p = t[line_e.split(" ")[e]][line_f.split(" ")[f]]
                if probability < p:
                    probability = p
                    alignment = e+1
            # Check NULL alignment
            if probability < t["NULL"][line_f.split(" ")[f]]:
                probability = t["NULL"][line_f.split(" ")[f]]
                alignment = 0
            alignments.append(alignment)
        print(line_e, file=Align_G)
        print(line_f, file=Align_G)
        print(alignments, file=Align_G)
        print("", file=Align_G)
    source.close()
    foreign.close()
    Align_G.close()

# %%
def main():
    start_time = time.time()
    #Read in corpus, initialize t(f|e) for each unique English word-foreign word combo
    t = init_t("de-en.en","de-en.de")
    #Run  5 iterations of the EM algorithm for IBM model 1
    model1("de-en.en","de-en.de",t)
    #Find alignments for the first 20 sentence pairs in the training data, save to output
    model_alignments_Ge_en(t)
    logging.warning("--- %s seconds ---" % (time.time() - start_time))

if __name__ == '__main__':     # if the function is the main function ...
    main()
# Out:
# WARNING:root:--- 2391.456472158432 seconds ---

# %%
file_G = open('Align-German','r') 
print(file_G.read())
# Out:
# Resumption of the session
# Wiederaufnahme der Sitzungsperiode
# [1, 2, 4]
#
# I declare resumed the session of the European Parliament adjourned on Friday 17 December 1999 , and I would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
# Ich erklÃ¤re die am Freitag , dem 17. Dezember unterbrochene Sitzungsperiode des EuropÃ¤ischen Parlaments fÃ¼r wiederaufgenommen , wÃ¼nsche Ihnen nochmals alles Gute zum Jahreswechsel und hoffe , daÃŸ Sie schÃ¶ne Ferien hatten .
# [1, 2, 4, 2, 12, 16, 24, 2, 14, 2, 5, 39, 8, 2, 14, 2, 16, 2, 25, 2, 2, 2, 2, 2, 17, 32, 16, 33, 25, 2, 2, 2, 0]
#
# Although , as you will have seen , the dreaded ' millennium bug ' failed to materialise , still the people in a number of countries suffered a series of natural disasters that truly were dreadful .
# Wie Sie feststellen konnten , ist der gefÃ¼rchtete " Millenium-Bug " nicht eingetreten . Doch sind BÃ¼rger einiger unserer Mitgliedstaaten Opfer von schrecklichen Naturkatastrophen geworden .
# [10, 4, 10, 10, 2, 24, 11, 10, 10, 10, 10, 15, 10, 0, 10, 21, 10, 10, 10, 10, 27, 15, 10, 31, 27, 0]
#
# You have requested a debate on this subject in the course of the next few days , during this part-session .
# Im Parlament besteht der Wunsch nach einer Aussprache im Verlauf dieser Sitzungsperiode in den nÃ¤chsten Tagen .
# [16, 16, 16, 12, 3, 3, 20, 5, 18, 16, 7, 20, 9, 10, 14, 16, 0]
#
# In the meantime , I should like to observe a minute ' s silence , as a number of Members have requested , on behalf of all the victims concerned , particularly those of the terrible storms , in the various countries of the European Union .
# Heute mÃ¶chte ich Sie bitten - das ist auch der Wunsch einiger Kolleginnen und Kollegen - , allen Opfern der StÃ¼rme , insbesondere in den verschiedenen LÃ¤ndern der EuropÃ¤ischen Union , in einer Schweigeminute zu gedenken .
# [3, 7, 5, 22, 3, 3, 3, 18, 41, 12, 22, 3, 20, 20, 20, 3, 4, 27, 3, 12, 3, 4, 32, 39, 13, 41, 42, 12, 45, 46, 4, 39, 14, 14, 8, 3, 0]
#
# Please rise , then , for this minute ' s silence .
# Ich bitte Sie , sich zu einer Schweigeminute zu erheben .
# [2, 2, 1, 3, 11, 2, 11, 11, 2, 2, 0]
#
# ( The House rose and observed a minute ' s silence )
# ( Das Parlament erhebt sich zu einer Schweigeminute . )
# [1, 4, 4, 4, 11, 11, 11, 11, 0, 12]
#
# Madam President , on a point of order .
# Frau PrÃ¤sidentin , zur GeschÃ¤ftsordnung .
# [1, 1, 3, 6, 8, 0]
#
# You will be aware from the press and television that there have been a number of bomb explosions and killings in Sri Lanka .
# Wie Sie sicher aus der Presse und dem Fernsehen wissen , gab es in Sri Lanka mehrere Bombenexplosionen mit zahlreichen Toten .
# [17, 1, 17, 5, 16, 7, 8, 23, 17, 17, 3, 23, 11, 21, 22, 22, 17, 17, 17, 17, 17, 0]
#
# One of the people assassinated very recently in Sri Lanka was Mr Kumar Ponnambalam , who had visited the European Parliament just a few months ago .
# Zu den Attentatsopfern , die es in jÃ¼ngster Zeit in Sri Lanka zu beklagen gab , zÃ¤hlt auch Herr Kumar Ponnambalam , der dem EuropÃ¤ischen Parlament erst vor wenigen Monaten einen Besuch abgestattet hatte .
# [5, 3, 5, 15, 3, 1, 8, 7, 7, 8, 9, 9, 17, 5, 10, 15, 5, 4, 12, 5, 9, 15, 2, 10, 20, 21, 5, 7, 26, 5, 5, 5, 5, 17, 0]
#
# Would it be appropriate for you , Madam President , to write a letter to the Sri Lankan President expressing Parliament 's regret at his and the other violent deaths in Sri Lanka and urging her to do everything she possibly can to seek a peaceful reconciliation to a very difficult situation ?
# WÃ¤re es angemessen , wenn Sie , Frau PrÃ¤sidentin , der PrÃ¤sidentin von Sri Lanka in einem Schreiben das Bedauern des Parlaments zum gewaltsamen Tod von Herrn Ponnambalam und anderen BÃ¼rgern von Sri Lanka Ã¼bermitteln und sie auffordern wÃ¼rden , alles in ihrem KrÃ¤ften stehende zu tun , um nach einer friedlichen LÃ¶sung dieser sehr schwierigen Situation zu suchen ?
# [1, 2, 1, 7, 20, 6, 7, 8, 8, 7, 16, 8, 44, 17, 17, 31, 4, 1, 23, 1, 22, 14, 35, 1, 1, 44, 35, 17, 26, 1, 1, 44, 17, 17, 1, 26, 40, 1, 35, 7, 39, 31, 1, 1, 1, 11, 38, 7, 1, 41, 1, 1, 1, 51, 50, 51, 52, 11, 1, 53]
#
# Yes , Mr Evans , I feel an initiative of the type you have just suggested would be entirely appropriate .
# Ja , Herr Evans , ich denke , daÃŸ eine derartige Initiative durchaus angebracht ist .
# [19, 2, 3, 4, 2, 6, 19, 2, 7, 7, 19, 9, 19, 19, 16, 0]
#
# If the House agrees , I shall do as Mr Evans has suggested .
# Wenn das Haus damit einverstanden ist , werde ich dem Vorschlag von Herrn Evans folgen .
# [1, 1, 3, 7, 4, 13, 5, 7, 6, 4, 13, 3, 4, 11, 13, 0]
#
# Madam President , on a point of order .
# Frau PrÃ¤sidentin , zur GeschÃ¤ftsordnung .
# [1, 1, 3, 6, 8, 0]
#
# I would like your advice about Rule 143 concerning inadmissibility .
# KÃ¶nnten Sie mir eine Auskunft zu Artikel 143 im Zusammenhang mit der UnzulÃ¤ssigkeit geben ?
# [5, 4, 9, 6, 5, 5, 7, 5, 9, 5, 4, 7, 5, 5, 5]
#
# My question relates to something that will come up on Thursday and which I will then raise again .
# Meine Frage betrifft eine Angelegenheit , die am Donnerstag zur Sprache kommen wird und auf die ich dann erneut verweisen werde .
# [1, 2, 3, 8, 17, 4, 13, 11, 11, 1, 17, 17, 7, 12, 9, 13, 14, 16, 17, 17, 2, 0]
#
# The Cunha report on multiannual guidance programmes comes before Parliament on Thursday and contains a proposal in paragraph 6 that a form of quota penalties should be introduced for countries which fail to meet their fleet reduction targets annually .
# Das Parlament wird sich am Donnerstag mit dem Cunha-Bericht Ã¼ber mehrjÃ¤hrige Ausrichtungsprogramme befassen , der in Absatz 6 vorschlÃ¤gt , daÃŸ LÃ¤nder , die ihr Soll zur Flottenverkleinerung nicht erfÃ¼llen , jÃ¤hrlich mit einer Art Quotenstrafe belegt werden sollen .
# [2, 10, 2, 8, 12, 12, 37, 22, 2, 4, 2, 2, 2, 27, 23, 17, 2, 19, 2, 27, 20, 30, 27, 31, 2, 2, 28, 2, 25, 2, 27, 2, 37, 18, 2, 2, 2, 34, 2, 0]
#
# It says that this should be done despite the principle of relative stability .
# Und zwar sollen derartige Strafen trotz des Grundsatzes der relativen StabilitÃ¤t verhÃ¤ngt werden .
# [2, 2, 2, 2, 2, 8, 10, 2, 11, 12, 13, 2, 6, 0]
#
# I believe that the principle of relative stability is a fundamental legal principle of the common fisheries policy and a proposal to subvert it would be legally inadmissible .
# Ich meine , daÃŸ der Grundsatz der relativen StabilitÃ¤t einen elementaren Rechtsgrundsatz der gemeinsamen Fischereipolitik darstellt und ein Vorschlag , diesen zu unterlaufen , rechtlich unzulÃ¤ssig wÃ¤re .
# [1, 17, 26, 3, 6, 5, 6, 7, 8, 17, 17, 17, 6, 16, 17, 17, 19, 12, 21, 26, 17, 22, 17, 26, 17, 17, 17, 0]
#
# I want to know whether one can raise an objection of that kind to what is merely a report , not a legislative proposal , and whether that is something I can competently do on Thursday .
# Ich mÃ¶chte wissen , ob es mÃ¶glich ist , einen Einwand gegen ein Dokument zu erheben , bei dem es sich lediglich um einen Bericht und keinen Legislativvorschlag handelt , und ob ich befugt bin , dies am Donnerstag zu tun .
# [1, 2, 4, 20, 5, 23, 10, 16, 20, 6, 10, 10, 23, 10, 3, 8, 20, 17, 15, 23, 13, 17, 10, 6, 19, 26, 10, 10, 10, 20, 26, 5, 1, 10, 30, 20, 8, 36, 36, 3, 34, 0]
